# %% [markdown]
# <a href="https://colab.research.google.com/github/DATA-Meta/AI_NN/blob/main/NLP_task%2002_with_spacy_lg_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import spacy

# %%
nlp = spacy.load('en_core_web_lg')

# %%
# nlp = spacy.load('en_core_web_sm')  # model for NLP

# %%
# reading the small english language
file_path = '/content/Cover letter.txt'
with open(file_path, 'r') as file:
    text = file.read()

# %%
# processing the text using spacy
doc = nlp(text)
print(doc)
# Out:
# Experienced data analyst with strong technical skills in SQL, Python, and data visualization tools. Proven track record of leveraging data to drive business decisions and optimize performance. Effective communicator and collaborator, with the ability to present complex findings to non-technical stakeholders.
# Elon Musk.
# Tesla.
# Google.

# %%
#extracting the small language models
print('Named Entities:')
for ent in doc.ents:
    print(f'{ent.text} - {ent.label_}')
# Out:
# Named Entities:
# SQL - ORG
# Python - ORG
# Elon Musk - PERSON
# Tesla - ORG
# Google - ORG

# %%
# using another models like en_Core_Web_Sm , en_Core_Web_md, en_Core_Web_ly, en_Core_Web_trf
