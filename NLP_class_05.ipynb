# %%
import tensorflow  as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Embedding, Dense, Flatten
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.datasets import imdb
import numpy as np
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1781531479.382923    3870 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1781531479.398831    3870 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1781531495.172800    3870 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1781531507.089373    3870 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1781531507.090313    3870 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %%
#Load Dataset

(x_train,y_train),(x_test,y_test) = imdb.load_data(num_words=10000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
# Data Processing - Tokenizing and Padding

max_len = 100
x_train = pad_sequences(x_train,maxlen=max_len)
x_test = pad_sequences(x_test,maxlen=max_len)

print('Training Data Shape:',x_train.shape)
print('Testing Data Shape:',x_test.shape)
# Out:
# Training Data Shape: (25000, 100)
# Testing Data Shape: (25000, 100)

# %%
model = Sequential([Embedding(input_dim=10000,output_dim=128,input_length=max_len),
          Flatten(),
          Dense(32,activation = 'relu'),
          Dense(1,activation = 'sigmoid')
          ])
# Out:
# /workspaces/AI_NN/.venv/lib/python3.13/site-packages/keras/src/layers/core/embedding.py:103: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
# Out:
# E0000 00:00:1781531599.303547    3870 cuda_platform.cc:52] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %%
history = model.fit(
    x_train,
    y_train,
    epochs=10,
    batch_size=32,
    validation_data=(x_test,y_test))
# Out:
# Epoch 1/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 13s 15ms/step - accuracy: 0.7933 - loss: 0.4226 - val_accuracy: 0.8459 - val_loss: 0.3430
# Epoch 2/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - accuracy: 0.9673 - loss: 0.0938 - val_accuracy: 0.8096 - val_loss: 0.5368
# Epoch 3/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.9964 - loss: 0.0124 - val_accuracy: 0.8238 - val_loss: 0.6893
# Epoch 4/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9996 - loss: 0.0022 - val_accuracy: 0.8218 - val_loss: 0.7606
# Epoch 5/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 1.0000 - loss: 3.0713e-04 - val_accuracy: 0.8261 - val_loss: 0.7947
# Epoch 6/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 1.0000 - loss: 8.1182e-05 - val_accuracy: 0.8274 - val_loss: 0.8193
# Epoch 7/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 1.0000 - loss: 4.5916e-05 - val_accuracy: 0.8283 - val_loss: 0.8419
# Epoch 8/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 1.0000 - loss: 2.7553e-05 - val_accuracy: 0.8290 - val_loss: 0.8631
# Epoch 9/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - accuracy: 1.0000 - loss: 1.7743e-05 - val_accuracy: 0.8298 - val_loss: 0.8831
# Epoch 10/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 1.0000 - loss: 1.1570e-05 - val_accuracy: 0.8304 - val_loss: 0.9040

# %%
loss,accuracy = model.evaluate(x_test,y_test)
print('Loss:',loss)
print('Accuracy:',accuracy)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8304 - loss: 0.9040
# Loss: 0.9040180444717407
# Accuracy: 0.8304399847984314
